# %%
import json

import pandas as pd

from tool.factory import get_tool_handle
import util
import db_util
from tool import SATResult

# %%
selected_trials = {
    "codechecker": "codechecker-trial4",
    "codeql": "codeql-trial4",
    "cppcheck": "cppcheck-trial1b",
    "flawfinder": "flawfinder-trial2",
    "infer": "infer-trial3",
}

# %%
active_database = "restored_db"

# transaction database
conn, cur = db_util.connect_database(database=active_database)

# %% [markdown]
# ## Define Target VCC

# %%
# select a VCC to view the warnings
project = "danbloomberg/leptonica"
target_vcc = "316b85bbabfbb1072a9e3b38794c732aa940af4d"

# %%
output_filename = util.get_output_filename(
    project=project, commit_sha=target_vcc
)

# %%
selected_vcc_information_df = pd.read_csv(
    "../output_analysis/selected-vcc-information.csv"
)
print("VCC information")

vcc_dict = selected_vcc_information_df[selected_vcc_information_df["vcc_commit_sha"]==target_vcc].iloc[0].to_dict()

print("CVE: ", "https://nvd.nist.gov/vuln/detail/" + vcc_dict["cve"])
print(json.dumps(vcc_dict, indent=4))
# Out:
# VCC information
# CVE:  https://nvd.nist.gov/vuln/detail/CVE-2018-7186
# {
#     "project": "danbloomberg/leptonica",
#     "cve": "CVE-2018-7186",
#     "cwe": "664",
#     "vcc_commit_sha": "316b85bbabfbb1072a9e3b38794c732aa940af4d",
#     "changed_files": 72,
#     "changed_functions": 131,
#     "changed_lines": 2157,
#     "changed_files_loc": 33567,
#     "changed_functions_loc": 7815,
#     "vulnerable_files": 3,
#     "vulnerable_functions": 4,
#     "vulnerable_lines": 8,
#     "vulnerable_files_loc": 2303,
#     "vulnerable_functions_loc": 155
# }

# %% [markdown]
# ## Find vulnerable functions in VCC

# %%
vcc_commit_changes = db_util.get_commit_changes(
            cur=cur, commit_sha=target_vcc
        )
# filter out changes when vcc is also fixing commit
vcc_commit_changes = [
    c for c in vcc_commit_changes if c["commit_type"] == "vcc"
]

# fixing changes
relevant_changes = db_util.get_relevant_vcc_changes(
    cur=cur, vcc_commit_sha=target_vcc
)
combined_fixing_changes = []

# vcc files
vcc_files = set([change["file_name"] for change in vcc_commit_changes])

for relevant_change in relevant_changes:
    fixing_commit_sha = relevant_change["fixing_commit_sha"]
    fixing_changes = db_util.get_commit_changes(
        cur=cur, commit_sha=fixing_commit_sha
    )
    # filter out changes when fixing commit is also vcc
    combined_fixing_changes += [
        c for c in fixing_changes if c["commit_type"] == "fixing"
    ]


fixing_files = set(
    [change["file_name"] for change in combined_fixing_changes]
)

vulnerable_files = set(
    [
        f
        for f in vcc_files
        if
        # f in fixing_files
        util.is_changed_file_later_fixed(
            project=project,
            vcc_changed_file=f,
            fixing_files=fixing_files,
        )
        and util._is_c_or_cpp_file(filename=f)
    ]
)

fixing_functions = set(
    [
        change["function_name"]
        for change in combined_fixing_changes
        if change["function_name"] != "N/A"
    ]
)

vcc_functions = set(
    [
        change["function_name"]
        for change in vcc_commit_changes
        if change["function_name"] != "N/A"
    ]
)

# %%
vulnerable_files = set(
    [
        f
        for f in vcc_files
        if
        # f in fixing_files
        util.is_changed_file_later_fixed(
            project=project,
            vcc_changed_file=f,
            fixing_files=fixing_files,
        )
        and util._is_c_or_cpp_file(filename=f)
    ]
)

vulnerable_functions = set(
    [f for f in vcc_functions if f in fixing_functions]
)

# %%
# find changed functions / line numbers - see analysis_calculate.py
changed_functions_info = set(
    [
        (
            c["file_name"],
            c["function_name"],
            c["function_nloc"],
            c["function_start_line"],
            c["function_end_line"],
        )
        for c in vcc_commit_changes
        if util._is_c_or_cpp_file(filename=c["file_name"])
        and c["function_name"] != "N/A"
    ]
)

#  find vulnerable functions / line numbers 
vulnerable_functions_start_end_lines = set(
    [
        (
            c["file_name"],
            c["function_name"],
            c["function_start_line"],
            c["function_end_line"],
            c["function_nloc"],
        )
        for c in vcc_commit_changes
        if c["file_name"] in vulnerable_files
        and c["function_name"] in vulnerable_functions
    ]
)

# %% [markdown]
# ## Vulnerable Functions

# %%
print("commit url", "https://github.com/" + project + "/commit/" + target_vcc)
print(json.dumps(list(vulnerable_functions_start_end_lines), indent=4))
# Out:
# commit url https://github.com/danbloomberg/leptonica/commit/316b85bbabfbb1072a9e3b38794c732aa940af4d
# [
#     [
#         "src/ptabasic.c",
#         "ptaReadStream",
#         501,
#         540,
#         35
#     ],
#     [
#         "src/sel1.c",
#         "selReadStream",
#         1346,
#         1386,
#         33
#     ],
#     [
#         "src/gplot.c",
#         "gplotRead",
#         675,
#         748,
#         65
#     ],
#     [
#         "src/gplot.c",
#         "gplotMakeOutput",
#         348,
#         376,
#         22
#     ]
# ]

# %% [markdown]
# ## Warnings within Vulnerable Functions

# %%
for tool, trial in selected_trials.items():
    print("tool: ", tool)
    tool_handle = get_tool_handle(name=tool)
    
    try:
        warnings = tool_handle.get_transaction_result(
            output_filename=output_filename
        )
    except UnboundLocalError:
        print("result not found, skip")
        continue

    # only filter warnings in vulnerable functions
    vulnerable_warnings = []
    w:SATResult
    for w in warnings:
        for fn in vulnerable_functions_start_end_lines:
            if fn[0] == w.location_file and (
                (
                    int(fn[2]) <= int(w.location_start_line)
                    and int(w.location_start_line) <= int(fn[3])
                )
                or (
                    int(fn[2]) <= int(w.location_end_line)
                    and int(w.location_end_line) <= int(fn[3])
                )
            ):
                vulnerable_warnings.append(w)

    vulnerable_warnings = list(set(vulnerable_warnings))

    print(json.dumps([w.to_dict() for w in vulnerable_warnings], indent=4))

    print("======================================================")
# Out:
# tool:  codechecker
# []
# ======================================================
# tool:  codeql
# [
#     {
#         "location_hash": "59e7f45e20ca7726:1",
#         "location_file": "src/sel1.c",
#         "location_start_line": 1366,
#         "location_start_column": 45,
#         "location_end_line": -1,
#         "location_end_column": 52,
#         "warning_rule_id": "cpp/unbounded-write",
#         "warning_rule_name": "Unbounded write",
#         "warning_message": "This 'sscanf string argument' with input from [linebuf](1) may overflow the destination.",
#         "warning_weakness": "CWE-120,CWE-787,CWE-805",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "c0175552336b8f38:1",
#         "location_file": "src/gplot.c",
#         "location_start_line": 714,
#         "location_start_column": 41,
#         "location_end_line": -1,
#         "location_end_column": 50,
#         "warning_rule_id": "cpp/missing-check-scanf",
#         "warning_rule_name": "Missing return-value check for a 'scanf'-like function",
#         "warning_message": "This variable is read, but may not have been written. It should be guarded by a check that the [call to fscanf](1) returns at least 1.",
#         "warning_weakness": "CWE-252,CWE-253",
#         "warning_severity": "MEDIUM"
#     }
# ]
# ======================================================
# tool:  cppcheck
# []
# ======================================================
# tool:  flawfinder
# [
#     {
#         "location_hash": "75a770010e0ce1da375e3d96b95e38422a6e111de859cf1c07769f14e004a27d",
#         "location_file": "src/gplot.c",
#         "location_start_line": 730,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 48,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "71ff0c95d6287b6f8cd1bbff7f3c9b26dc2214b495036697d31829776aa2c910",
#         "location_file": "src/gplot.c",
#         "location_start_line": 688,
#         "location_start_column": 15,
#         "location_end_line": -1,
#         "location_end_column": 45,
#         "warning_rule_id": "FF1040",
#         "warning_rule_name": "misc/fopen",
#         "warning_message": "misc/fopen:Check when opening files - can an attacker redirect it (via symlinks), force the opening of special file type (e.g., device files), move things around to create a race condition, control its ancestors, or change its contents? (CWE-362).",
#         "warning_weakness": "CWE-362",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "e9d81f64903c1ffd66f90205c5cc4e753c96f0f88c50ea99073436167abcbcbf",
#         "location_file": "src/gplot.c",
#         "location_start_line": 742,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 56,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "843c05aa4be48c80feb4fe37adcc156dec100d3a26f5879a8aa1ccfc86cd33bc",
#         "location_file": "src/gplot.c",
#         "location_start_line": 691,
#         "location_start_column": 11,
#         "location_end_line": -1,
#         "location_end_column": 54,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "d55741c380a5d30fdca6d49d53574a8f90c196f99724c83eff2d2c2ccfef8ae1",
#         "location_file": "src/sel1.c",
#         "location_start_line": 1380,
#         "location_start_column": 18,
#         "location_end_line": -1,
#         "location_end_column": 35,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "6269db0710c413c28341474adfede6804d011b276855c9eb95a403aa50f957c3",
#         "location_file": "src/gplot.c",
#         "location_start_line": 734,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 41,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "2c455144bb71548b8a384fde493b581286ceecad5edc7ea0e13a5d16307b2c83",
#         "location_file": "src/gplot.c",
#         "location_start_line": 738,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 43,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "c71ebcd8f18675814ec0721c76c5faf45ea9503c489ebdf9f94867b44740b81d",
#         "location_file": "src/gplot.c",
#         "location_start_line": 363,
#         "location_start_column": 9,
#         "location_end_line": -1,
#         "location_end_column": 67,
#         "warning_rule_id": "FF1019",
#         "warning_rule_name": "format/snprintf",
#         "warning_message": "format/snprintf:If format strings can be influenced by an attacker, they can be exploited, and note that sprintf variations do not always \\0-terminate (CWE-134).",
#         "warning_weakness": "CWE-134",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "b8d03cad71c4841f946f6d7ce850a299be3c3ffd3c44fc5d4237d6388f42e4df",
#         "location_file": "src/gplot.c",
#         "location_start_line": 701,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 48,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "251bebf29ebd792ab4bb897142a3e01c50dda695913730e15b4c7de7c3f38f7b",
#         "location_file": "src/gplot.c",
#         "location_start_line": 369,
#         "location_start_column": 8,
#         "location_end_line": -1,
#         "location_end_column": 65,
#         "warning_rule_id": "FF1019",
#         "warning_rule_name": "format/snprintf",
#         "warning_message": "format/snprintf:If format strings can be influenced by an attacker, they can be exploited, and note that sprintf variations do not always \\0-terminate (CWE-134).",
#         "warning_weakness": "CWE-134",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "d0e2a80392991db36730cbca0972411f6e90572ec5d22f32b86594329212a60b",
#         "location_file": "src/ptabasic.c",
#         "location_start_line": 513,
#         "location_start_column": 9,
#         "location_end_line": -1,
#         "location_end_column": 58,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "0a59887a2ef2fa613ae77e05be8d7354c2fe0d0c54416f3d8dafee2fc519ed0c",
#         "location_file": "src/gplot.c",
#         "location_start_line": 350,
#         "location_start_column": 1,
#         "location_end_line": -1,
#         "location_end_column": 26,
#         "warning_rule_id": "FF1013",
#         "warning_rule_name": "buffer/char",
#         "warning_message": "buffer/char:Statically-sized arrays can be improperly restricted, leading to potential overflows or other issues (CWE-119!/CWE-120).",
#         "warning_weakness": "CWE-119,CWE-120",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "687c6b005e7f2e9edcde822a977337f15b6921f4890a6c32dd5cc9dbe8caf7e3",
#         "location_file": "src/gplot.c",
#         "location_start_line": 374,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 26,
#         "warning_rule_id": "FF1044",
#         "warning_rule_name": "shell/system",
#         "warning_message": "shell/system:This causes a new program to execute and is difficult to use safely (CWE-78).",
#         "warning_weakness": "CWE-78",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "af5695f2179baa14c5705f7886dfd0fc970851b81951cefa5cf0d8f60f2a4e0e",
#         "location_file": "src/sel1.c",
#         "location_start_line": 1379,
#         "location_start_column": 22,
#         "location_end_line": -1,
#         "location_end_column": 58,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "05c6d792f23445bbab243414164d760834ff3324ed2f5073b2ea61a4f1dadadf",
#         "location_file": "src/gplot.c",
#         "location_start_line": 709,
#         "location_start_column": 12,
#         "location_end_line": -1,
#         "location_end_column": 39,
#         "warning_rule_id": "FF1022",
#         "warning_rule_name": "buffer/strlen",
#         "warning_message": "buffer/strlen:Does not handle strings that are not \\0-terminated; if given one it may perform an over-read (it could cause a crash if unprotected) (CWE-126).",
#         "warning_weakness": "CWE-126",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "70375be13937232a2218428592a37d7028fb77656c99786b91840a160ec005d4",
#         "location_file": "src/ptabasic.c",
#         "location_start_line": 528,
#         "location_start_column": 17,
#         "location_end_line": -1,
#         "location_end_column": 58,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "c34304139019df4f495c7e349ae3bdf43339986fe817a4e519614b6f64284805",
#         "location_file": "src/ptabasic.c",
#         "location_start_line": 533,
#         "location_start_column": 17,
#         "location_end_line": -1,
#         "location_end_column": 60,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "c2ad7aff953dfe623c31ebf4c73615b04dc4c9d6046c664832363a4aa66fee4d",
#         "location_file": "src/gplot.c",
#         "location_start_line": 741,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 66,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "3c489217995c60d123acf6f6c4507e3a426a86e7d6d232598d5cbca21d66de91",
#         "location_file": "src/gplot.c",
#         "location_start_line": 712,
#         "location_start_column": 12,
#         "location_end_line": -1,
#         "location_end_column": 39,
#         "warning_rule_id": "FF1022",
#         "warning_rule_name": "buffer/strlen",
#         "warning_message": "buffer/strlen:Does not handle strings that are not \\0-terminated; if given one it may perform an over-read (it could cause a crash if unprotected) (CWE-126).",
#         "warning_weakness": "CWE-126",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "54ecc89b495e31275e7911c47c1c6663dea54f1e13d42933c9b0655694653aca",
#         "location_file": "src/gplot.c",
#         "location_start_line": 365,
#         "location_start_column": 9,
#         "location_end_line": -1,
#         "location_end_column": 34,
#         "warning_rule_id": "FF1019",
#         "warning_rule_name": "format/snprintf",
#         "warning_message": "format/snprintf:If format strings can be influenced by an attacker, they can be exploited, and note that sprintf variations do not always \\0-terminate (CWE-134).",
#         "warning_weakness": "CWE-134",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "57308f7d733467396f7ff39d21f3c69b7d2658e4f138a608235b4c5e328544b3",
#         "location_file": "src/sel1.c",
#         "location_start_line": 1349,
#         "location_start_column": 1,
#         "location_end_line": -1,
#         "location_end_column": 30,
#         "warning_rule_id": "FF1013",
#         "warning_rule_name": "buffer/char",
#         "warning_message": "buffer/char:Statically-sized arrays can be improperly restricted, leading to potential overflows or other issues (CWE-119!/CWE-120).",
#         "warning_weakness": "CWE-119,CWE-120",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "a7762b63475be2efe37911ea52d788024ca088b284fb73e3269a8f62f1d7c5a8",
#         "location_file": "src/sel1.c",
#         "location_start_line": 1368,
#         "location_start_column": 9,
#         "location_end_line": -1,
#         "location_end_column": 61,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "9abc2c34ea69c4cf9daaf23d41119fae6496ec1be600be0e551765139805119c",
#         "location_file": "src/sel1.c",
#         "location_start_line": 1366,
#         "location_start_column": 5,
#         "location_end_line": -1,
#         "location_end_column": 54,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/sscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "8bb1b40015c11243593ebe5e3d32b2799631baac73f98adbc32cc036e39d0994",
#         "location_file": "src/ptabasic.c",
#         "location_start_line": 517,
#         "location_start_column": 9,
#         "location_end_line": -1,
#         "location_end_column": 76,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "fbaadc7e1a857def4df6f984e44e5d068b802fd2d0a80b573e2a2521a43e3b04",
#         "location_file": "src/sel1.c",
#         "location_start_line": 1377,
#         "location_start_column": 18,
#         "location_end_line": -1,
#         "location_end_column": 37,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "e60211f2764e7a8102af921a3ea88d9f4e006c9df51f4423f4b1cd4a5a9184a6",
#         "location_file": "src/sel1.c",
#         "location_start_line": 1358,
#         "location_start_column": 9,
#         "location_end_line": -1,
#         "location_end_column": 57,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "6879580c56abf50f93ffc19c0999a1e87e2a9d77aec4476867570b5b75187d1b",
#         "location_file": "src/gplot.c",
#         "location_start_line": 728,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 56,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "672f082a76a728871712328f04ce7b589c3d7739af89b5bc3f43f8a5721c6e0c",
#         "location_file": "src/gplot.c",
#         "location_start_line": 703,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 60,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "c7fed714bf32385f8dade26ee41dd753be1e8cc73190b35ab7b711401912bc60",
#         "location_file": "src/gplot.c",
#         "location_start_line": 732,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 46,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "49956041a6c05bd3e7bc742af4810d909b987f786b3aa96c74e60e656755d0de",
#         "location_file": "src/gplot.c",
#         "location_start_line": 736,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 43,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "7c31ce260c113d634e152e0716802141e4b7ed73dc10d6a5b097cac96e994ea5",
#         "location_file": "src/ptabasic.c",
#         "location_start_line": 503,
#         "location_start_column": 1,
#         "location_end_line": -1,
#         "location_end_column": 25,
#         "warning_rule_id": "FF1013",
#         "warning_rule_name": "buffer/char",
#         "warning_message": "buffer/char:Statically-sized arrays can be improperly restricted, leading to potential overflows or other issues (CWE-119!/CWE-120).",
#         "warning_weakness": "CWE-119,CWE-120",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "5dbc72cba56e11be135f4700fd0cd7158d4e757102d2f38b89351668b4e56c31",
#         "location_file": "src/gplot.c",
#         "location_start_line": 706,
#         "location_start_column": 11,
#         "location_end_line": -1,
#         "location_end_column": 37,
#         "warning_rule_id": "FF1022",
#         "warning_rule_name": "buffer/strlen",
#         "warning_message": "buffer/strlen:Does not handle strings that are not \\0-terminated; if given one it may perform an over-read (it could cause a crash if unprotected) (CWE-126).",
#         "warning_weakness": "CWE-126",
#         "warning_severity": "LOW"
#     },
#     {
#         "location_hash": "d6f4d66171d5ee7008b8379f9314fde9e90c52d4c6299b2100152f2b3534c7a2",
#         "location_file": "src/gplot.c",
#         "location_start_line": 744,
#         "location_start_column": 14,
#         "location_end_line": -1,
#         "location_end_column": 64,
#         "warning_rule_id": "FF1021",
#         "warning_rule_name": "buffer/fscanf",
#         "warning_message": "buffer/fscanf:The scanf() family's %s operation, without a limit specification, permits buffer overflows (CWE-120, CWE-20).",
#         "warning_weakness": "CWE-120,CWE-20",
#         "warning_severity": "LOW"
#     }
# ]
# ======================================================
# tool:  infer
# [
#     {
#         "location_hash": "sel1.c|selReadStream|DEAD_STORE",
#         "location_file": "src/sel1.c",
#         "location_start_line": 1377,
#         "location_start_column": 9,
#         "location_end_line": 1377,
#         "location_end_column": 9,
#         "warning_rule_id": "DEAD_STORE",
#         "warning_rule_name": "Dead Store",
#         "warning_message": "The value written to &ignore (type int) is never used.",
#         "warning_weakness": "CWE-1076",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "gplot.c|gplotRead|DEAD_STORE",
#         "location_file": "src/gplot.c",
#         "location_start_line": 701,
#         "location_start_column": 5,
#         "location_end_line": 701,
#         "location_end_column": 5,
#         "warning_rule_id": "DEAD_STORE",
#         "warning_rule_name": "Dead Store",
#         "warning_message": "The value written to &ignore (type int) is never used.",
#         "warning_weakness": "CWE-1076",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "gplot.c|gplotMakeOutput|DEAD_STORE",
#         "location_file": "src/gplot.c",
#         "location_start_line": 374,
#         "location_start_column": 5,
#         "location_end_line": 374,
#         "location_end_column": 5,
#         "warning_rule_id": "DEAD_STORE",
#         "warning_rule_name": "Dead Store",
#         "warning_message": "The value written to &ignore (type int) is never used.",
#         "warning_weakness": "CWE-1076",
#         "warning_severity": "HIGH"
#     },
#     {
#         "location_hash": "gplot.c|gplotRead|NULL_DEREFERENCE",
#         "location_file": "src/gplot.c",
#         "location_start_line": 706,
#         "location_start_column": 11,
#         "location_end_line": 706,
#         "location_end_column": 11,
#         "warning_rule_id": "NULL_DEREFERENCE",
#         "warning_rule_name": "Null Dereference",
#         "warning_message": "pointer `title` last assigned on line 705 could be null and is dereferenced by call to `strlen()` at line 706, column 11.",
#         "warning_weakness": "CWE-476",
#         "warning_severity": "HIGH"
#     }
# ]
# ======================================================
